# %% [markdown]
# **My first program**

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# **Variable declaration **

# %%
a = 5
b = 10
sum=a+b
print(sum)
# Out:
# 15

# %% [markdown]
# **assignment 1**

# %%
import math
a=6
b=10
c=15
d=4
dif=a-b-c
mul=a*b*c
div=b/a
sqr=a*a
rem=b%a
root=math.sqrt(d)
print("Difference between", a , b,"and", c ,"is" ,dif )
print("Product of", a, b, "and",c,"is",mul)
print(b,"divided by",a,"is",div)
print("reminder of 10/6 is",rem)
print("Square root of",d,"is",root)
# Out:
# Difference between 6 10 and 15 is -19
# Product of 6 10 and 15 is 900
# 10 divided by 6 is 1.6666666666666667
# reminder of 10/6 is 4
# Square root of 4 is 2.0

# %% [markdown]
# **Data types**

# %% [markdown]
# **Sequence** data type
#
# Lists

# %%
lis=['hello','1','2','3.5']
print(lis)
# Out:
# ['hello', '1', '2', '3.5']

# %%
list2=['hey','4','5','6']
lis3=lis+list2
print(lis3)
# Out:
# ['hello', '1', '2', '3.5', 'hey', '4', '5', '6']

# %%
print(len(lis3))
# Out:
# 8

# %%
lis3.append("hello")
lis3
# Out:
# ['hello', '1', '2', '3.5', 'hey', '4', '5', '6', 'hello', 'hello']

# %%
lis3.append("100")
lis3
# Out:
# ['hello', '1', '2', '3.5', 'hey', '4', '5', '6', 'hello', 'hello', '100']

# %%
lis3.clear()
lis3
# Out:
# []

# %%
lis.sort()
lis
# Out:
# ['1', '2', '3.5', 'hello']

# %%
liss=["apple","cat","dog","zebra","owl"]
liss.sort()
liss
# Out:
# ['apple', 'cat', 'dog', 'owl', 'zebra']

# %% [markdown]
# **Tuples**

# %%
tuple1=("apple","cat","dog","zebra","owl")
tuple1
# Out:
# ('apple', 'cat', 'dog', 'zebra', 'owl')

# %%
tuple2=((1,10,100,"hey"))
tuple2
# Out:
# (1, 10, 100, 'hey')

# %%
lis=["hey","hello"]
print(lis[-1])
# Out:
# hello

# %%
tuple2=tuple2 * 2
tuple2
# Out:
# (1, 10, 100, 'hey', 1, 10, 100, 'hey')

# %%
y=tuple2.index(100)
print(y)
# Out:
# 2

# %% [markdown]
# **Type** **casting**

# %%
tuple1=("apple","cat","dog","zebra","owl")
y=list(tuple1)
print(type(y))
# Out:
# <class 'list'>

# %%
y[4]="ball"
y
# Out:
# ['apple', 'cat', 'dog', 'zebra', 'ball']

# %%
y.append("bat")
y
# Out:
# ['apple', 'cat', 'dog', 'zebra', 'ball', 'bat']

# %% [markdown]
# **SETS**

# %%
set1={"apple","red","blue","black"}
set1
# Out:
# {'apple', 'black', 'blue', 'red'}

# %%
set1.add('hey')
set1
# Out:
# {'apple', 'black', 'blue', 'hey', 'red'}

# %% [markdown]
# **Dictionaries**

# %%
dict1={"name":"Sumanth", "age":"20","Gender":"Male","age":"25"}
print(dict1)
# Out:
# {'name': 'Sumanth', 'age': '25', 'Gender': 'Male'}

# %% [markdown]
# **Condtional Statements**

# %% [markdown]
# ***If Else statements***

# %%
a=(input("Enter the value of a"))
b=input("Enter the value of b")
print(type(a))
print(type(b))
# Out:
# Enter the value of a10
# Enter the value of b20.5
# <class 'str'>
# <class 'str'>

# %%
if a>b:
 print("The value of a greter than b")
elif a==b:
  print(" Both a and b are same")
else:
 print("The value of b is greater than a")
# Out:
# The value of b is greater than a

# %% [markdown]
# **Looping statements**

# %% [markdown]
# ***while***

# %%
num=int(input("Enter the number"))
while num<=9:
 print("Number is single digit")
 break
while num>9 and num<=99:
 print("Number is double digit")
 break
# Out:
# Enter the number99
# Number is double digit

# %% [markdown]
# ***For loop***

# %%
for y in range(1,5,1):
 print(y)
# Out:
# 1
# 2
# 3
# 4

# %%
places=["Hubli","haveri","bangalore","dharwad"]
for x in places:
 print(x)
 if x=="Hubli":
  print("Found")
  break
# Out:
# Hubli
# Found

# %% [markdown]
# **Sum of odd and even numbers within a given range**

# %%
sum=0
n=int(input("Enter the value of n"))
for x in  range(1,n,2):
 sum=sum+x
print("The sum of first",n,"odd numbers is",sum)
# Out:
# Enter the value of n5
# The sum of first 5 odd numbers is 4

# %% [markdown]
# **Concept Of args**

# %%
def add(*b):
 sum=0
 for x in b:
  sum=sum+x
 return sum

print(add(1,2,3,100))
# Out:
# 106

# %% [markdown]
# **Concept Of kwargs**

# %%
def greet(**kwar):
  print("Hello")
  for key,value in kwar.items():
    print(value,end=" ")

greet(name="Sumanth",USN="01fe21bec080",Brach="EC")
# Out:
# Hello
# Sumanth 01fe21bec080 EC
